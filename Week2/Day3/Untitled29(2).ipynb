# %% [markdown]
# Défi quotidien : analyse des accidents d’avion et des décès

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# --- Task 1: Data Import and Cleaning ---

# Please provide the direct link to the 'Airplane Crashes and Fatalities until 2023' dataset.
# Once provided, uncomment the line below and replace 'YOUR_DATASET_LINK_HERE' with the actual link.
# df = pd.read_csv('YOUR_DATASET_LINK_HERE')

# Placeholder for data loading, waiting for the dataset link.
# For now, let's assume 'df' will be loaded with the data.
# Example if a local file is to be uploaded:
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv(list(uploaded.keys())[0])

# Initial cleaning steps (will be expanded once data is loaded):
# print("Initial DataFrame Info:")
# df.info()
# print("\nMissing values before cleaning:")
# print(df.isnull().sum())

# Further cleaning and preprocessing will follow once the data is available.
