# %% [markdown]
# # Daily Challenge - Precision Prompting for Control & Output Quality

# %% [markdown]
# ### What You’ll learn
#
# * How to apply advanced prompting techniques to shape the tone, structure, and format of AI-generated content
# * How to constrain AI responses using word limits, sentence counts, and output formats
# * How to guide the model to paraphrase, quote, or summarize text with precision
# * How to evaluate and revise prompts for better results
# How to detect and mitigate hallucinated or fabricated content

# %% [markdown]
# What you will create
#
# You’ll design, test, and refine a prompt that performs four different control tasks in a realistic content generation workflow. You’ll work through a full prompt development cycle:
#
# * Crafting a prompt with tone, structure, format, and length control
# * Evaluating the output for quality and accuracy
# * Mitigating hallucination risks
# * Enhancing clarity through quoting or paraphrasing techniques

# %% [markdown]
# #
# Étape 1 : Créer une invite qui contrôle le ton, le format et la durée

# %%
Input Text = """
Employees must ensure that all remote access to internal systems is established via the approved secure VPN.
Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used
to access proprietary data or sensitive communications. """

# %%
step1_prompt = """
You are an in-house writer tasked with simplifying company policies
for a newsletter intended for all employees.

Rewrite the text below while adhering to ALL of these guidelines:
1. Friendly and clear tone—as if you were explaining it to a coworker.
2. Format: bullet points only (no introductory or concluding sentences).
3. Paraphrase only: do not use the exact wording of the original text.
4. Total number of words: strictly fewer than 75. Count the words before responding.
5. Do not provide ANY explanations, notes, or comments outside of the bullet points.

Source text:
'Employees must ensure that all remote access to internal systems is established
via the approved secure VPN. Under no circumstances should unsecured connections or personal devices
lacking endpoint protection be used to access'
confidential data or sensitive communications.
"""

# %%
step1_output = """
• Always connect to internal systems via the company’s official VPN.
• Never use a public or unsecured Wi-Fi connection to access your work tools.
• Personal devices without approved security software are prohibited for viewing confidential data or sensitive communications.
"""

# %% [markdown]
# ### Étape 2 : Évaluer les résultats

# %%
evaluation = {
    ‘Relevance’: {
        ‘question’: ‘Does the result accurately reflect the source message?’,
        ‘score’: ‘✅ Yes’,
        ‘comment’: (
            'The three key points are retained: the requirement to use a VPN, '
            'prohibition of unsecured connections, and exclusion of '
            ‘unprotected personal devices. No critical information has been omitted.’
        )
    },
    ‘Clarity’: {
        ‘question’: ‘Is the message more accessible to non-technical staff?’,
        ‘score’: ' ✅ Yes',
        ‘comment’: (
            ‘Technical terms (“device protection,” “unsecured connections”) ’
            ‘have been replaced with everyday language (“approved security software,” ’
            '“public Wi-Fi”). The tone is informal, which improves readability.'
        )
    },
    ‘Structure’: {
        ‘question’: ‘Is the information presented in clear bullet points?’,
        ‘score’: ‘✅ Yes’,
        ‘comment’: (
            ‘3 distinct bullet points, without distracting headings or conclusions. ’
            'Each bullet point = one rule = one action. Format followed.'
        )
    },
    ‘Tone’: {
        ‘question’: ‘Is the language appropriate for internal communication?’,
        ‘score’: ' ✅ Yes',
        ‘comment’: (
            ‘Direct use of “you” and action verbs (“Log in,” “Never use”) ’
            'set a tone that is both friendly and clear. No legal jargon.'

# %% [markdown]
# Étape 3 : Détecter et atténuer les hallucinations

# %%
hallucinated_output_example = """
• Always use the approved VPN to connect to internal systems.
• Enable two-factor authentication (2FA) on all your devices.   ← ❌ HALLUCINATION
• Install ISO 27001-certified antivirus software on your personal devices.  ← ❌ HALLUCINATION
• Avoid public Wi-Fi networks when accessing sensitive data.
"""

# %%
step3_prompt_revised = """
You are an in-house writer tasked with simplifying company policies
for a newsletter intended for all employees.

Rewrite the text below while adhering to ALL of these constraints:
1. Your tone should be friendly and clear—as if you were explaining it to a coworker.
2. Format: bullet points only (no introductory or concluding sentences).
3. Paraphrase only: do not use the exact wording of the original text.
4. Total number of words: strictly fewer than 75.

⚠️ ANTI-HALLUCINATION RULES (mandatory):
- Paraphrase ONLY the content of the provided source text.
- Do NOT add ANY new recommendations, technologies, standards, or practices
  that are not in the text (e.g., no 2FA, no antivirus, no certification).
- If a piece of information is not in the text, do not make it up.
- Stay strictly within the scope of the two rules stated in the source.

Source text:
'''
Employees must ensure that all remote access to internal systems is established
via the approved secure VPN. Under no circumstances should unsecured connections or personal devices
lacking endpoint protection be used to access
confidential data or sensitive communications.'

"""

# %% [markdown]
# # Etape 4 :  Paraphrasing Deep Dive

# %%
step4_prompt = """
You are the onboarding manager at a tech company. You need to explain
an IT security rule to new interns who are starting their
first job and are unfamiliar with the company’s terminology.

Rewrite the text below for this audience, following these guidelines:
1. Maximum of 4 bullet points—not one more.
2. Short, simple sentences (max 15 words per bullet point).
3. No jargon: no terms like “terminals,” “VPN,” or “endpoint protection.”
   If a technical term is unavoidable, explain it in parentheses in 3 words or fewer.
4. Encouraging and supportive tone—use “you” and start at least one bullet point
   with a positive statement (what the intern MUST do).
5. Paraphrase only—no direct quotes from the original text.
6. Do not add any content not present in the source text.

Source text:
'Employees must ensure that all remote access to internal systems is established
via the approved secure VPN. Under no circumstances should unsecured connections or personal devices
lacking endpoint protection be used to access
confidential data or sensitive communications.'
"""

# %% [markdown]
# # Étape 5 : Variante d'extraction de citation directe

# %%
step5_prompt = """
You are an expert in internal communications. Your role is to identify the quote
that best represents a security policy text.

From the source text below, select ONLY ONE direct quote
(copied word for word from the original text) that best summarizes
the essential security requirement.

Rules:
- The quote must be enclosed in quotation marks, without any modifications.
- It must consist of a single sentence or clause (not the entire text).
- Below the quote, explain in one sentence why you chose it.
- Do not add any additional comments or rephrasing.

Source text:
'Employees must ensure that all remote access to internal systems is established
via the approved secure VPN. Under no circumstances should unsecured connections or personal devices
lacking endpoint protection be used to access
confidential data or sensitive communications.'
"""

step5_output_citation = (
    """Under no circumstances should unsecured connections or personal devices '
    'without endpoint protection should be used to access '
    ‘confidential data or sensitive communications."""
)
step5_output_reason = (
    """This sentence was chosen because it expresses the absolute prohibition """
